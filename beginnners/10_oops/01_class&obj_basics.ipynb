# %%
# Create a Python class named Greet that contains a method called sayhello().
# The method should print the message "Hello".



class Greet:
    def sayhello(self):
        print("hello")
a=Greet()  #object creation
a.sayhello()  #ojbect calling


#note:
#Pascal case should be followed while naming as each word's first name should be capital and no space should be there
#Snake case where underscore is used( should not used in oops)

#what happens internally


# Class: Greet
#         |
#         |---- sayhello()

# Object Created:
# a

# a.sayhello()
#      |
#      ↓
# method executes
#      |
#      ↓
# print("Hello")
# Out:
# hello

# %%
#2. Write a Python program to create a class Student.
# Create a method to store a student's name and another method to display a greeting message using that name.

class Student:
    def get_student(self, name):
        self.name=name
    def print_student(self):
        print("Hello dude" ,self.name)
        
stu=Student()
stu.get_student("Pranjal")
stu.print_student()
# Out:
# Hello dude Pranajl
