# %%
#1. What is a module in Python?
#Ans. A module is is a Python file(.py) that contains funcition, variables or classes which can be imported and reused in another program
# Out:
# hell

# %%
#2. How do you import a module in Python?
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#3. Write a simple Python module that contains a function to add two numbers.

import add_module
result=add_module.add(5,2)   #=> moduleName.functionName (now this function can be accessed otherwise python will imports module only not the funciton directly 
print(result)
# Out:
# 7

# %%
#4. How do you import specific functions from a module?
from add_module import add #this is an advanced way to import function too 
result=add(5,4)
print(result)

# %%
#5. What is the difference between `import module` and `from module import function`?

#import module imports the entire module 
#from module import function imports only a specific function from the module

# %%
#6. Create a module and import it into another script.

#I made a module of adding two nums in add_moduly.py and then imported it like import add_module and then moduleName.functionName(parameter)

# %%
#7. How do you list all functions in a module?

#dir(module)-> list everything inside module
print(dir(add_module))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add']

# %%
#8. What is the purpose of the `__name__` variable in a module?

# __name__ tells how a python file is being executed.
# directly run-> __name__=="__main__"
# imported as module-> __name__=="module_name"

def greet():
    print("Hello")
if __name__=="__main__":
    print("This file is running directly")
# Out:
# This file is running directly

# %%
#9. Explain how to use the `as` keyword when importing a module.
# as is used to give a short alias(nickname) to a module or function
import math as m
print(m.sqrt(81))   #math module is renamed to m
# Out:
# 9.0

# %%
#10. What is a package in Python?

# Ans. A package is a folder that contains multiple python modules.
# It helps organize large programs into structured directories.


# Module  → single .py file
# Package → folder containing modules

# %%
#11. How do you create a package in Python?

# A package is created by making a folder that contains Python modules and usually an __init__.py file.

# %%
#12. Import the `math` module and calculate the square root of a number.
import math 
print(math.sqrt(16))
# Out:
# 4.0

# %%
#13. Use the `random` module to generate a random number between 1 and 100.
import random
a=random.randint(1,100)
print(a)
# Out:
# 33

# %%
#14. How do you access the documentation for a module?
#Use the help() function to see the documentation of a module
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
#15. Explain the difference between standard libraries and third-party libraries.

# Standard Library:
# Libraries that come pre-installed with Python.
# They can be used directly without installation.

# Example:

# import math
# import random

# Third-Party Library:
# Libraries that are created by external developers and must be installed using pip before using them.

# Example:

# pip install numpy
# pip install pandas

# %%
#16. Write a program that uses the `time` module to pause execution for 2 seconds.
import time
for i in range(5):
    print(i)
    time.sleep(2)  #This pauses 2 seconds after every iteration.
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#17. What is the purpose of the `sys` module in Python?

#Ans.  The sys module provides functions and variables used to interact with the Python interpreter and the system.
# It helps in accessing command line arguments, system information, and program control.
import sys
print(sys.version)
# Out:
# 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]

# %%
#18. How can you check the current version of Python you are using in your code?
import sys
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=13, micro=5, releaselevel='final', serial=0)

# %%
#19. Import the `os` module and write a function to list all files in the current directory.
import os
files=os.listdir()     #os.listdir() returns a list of files and folders in the current directory.
print(files)
# Out:
# ['.venv', 'add_module.py', 'mods&libs.ipynb', '__pycache__']

# %%
#20. How do you handle exceptions when importing a module?
try:
    import numpy as np
    print("Module Imported successfully")
except ImportError:
    print("Plz install the mdule using pip")
# Out:
# Plz install the mdule using pip

# %%
#21. Create a module that contains a function to find the factorial of a number.
import factorial_module
print(factorial_module.factorial(4))
# Out:
# 24

# %%
#22. Explain the concept of namespace in relation to modules.

#Ans. A namespace is a container that stores names of variables, functions, and objects and maps them to their values.
# In modules, each module has its own namespace, so names inside one module do not conflict with names in another module.
# A namespace is a space where names are stored and managed so they remain unique.

# %%
#23. What is `pip` and how is it used?

#Ans. pip is a package manager for Python used to install, update, and remove third-party libraries.
# It downloads packages from PyPI (Python Package Index).

# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 4.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/12.3 MB 10.4 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.3 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 11.2 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#24. Install a package using `pip` and import it into your script.
import numpy as np    #already installed numpy
arr=  np.array([1,2, 3])
print(arr)
# Out:
# [1 2 3]

# %%
#25. Use the `json` module to parse a JSON string.
import json

data = '{"name":"Pranjal","age":20}'

python_data = json.loads(data)

print(python_data)
# Out:
# {'name': 'Pranjal', 'age': 20}
